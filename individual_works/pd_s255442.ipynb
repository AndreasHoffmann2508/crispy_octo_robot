# %% [markdown]
# # Introduction

# %% [markdown]
# Hopefully, this short tutorial can show you a lot of different commands that will help you gain the most insights into your dataset.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\malth\miniforge3\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\malth\miniforge3\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\malth\miniforge3\lib\site-packages (from seaborn) (2.3.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\malth\miniforge3\lib\site-packages (from seaborn) (3.9.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\malth\miniforge3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\malth\miniforge3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\malth\miniforge3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\malth\miniforge3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\malth\miniforge3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\malth\miniforge3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\malth\miniforge3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\malth\miniforge3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\malth\miniforge3\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\malth\miniforge3\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\malth\miniforge3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
def load_data_from_google_drive(url):
    url_processed='https://drive.google.com/uc?id=' + url.split('/')[-2]
    df = pd.read_csv(url_processed)
    return df

# %% [markdown]
# I am putting this function, because of the layout it is to hard to get the utils file

# %% [markdown]
# # Loading in Data

# %% [markdown]
# The first step in any ML problem is identifying what format your data is in, and then loading it into whatever framework you're using. For Kaggle compeitions, a lot of data can be found in CSV files, so that's the example we're going to use.

# %% [markdown]
# We're going to be looking at a sports dataset that shows the results from NCAA basketball games from 1985 to 2016. This dataset is in a CSV file, and the function we're going to use to read in the file is called **pd.read_csv()**. This function returns a **dataframe** variable. The dataframe is the golden jewel data structure for Pandas. It is defined as "a two-dimensional size-mutable, potentially heterogeneous tabular data structure with labeled axes (rows and columns)".

# %% [markdown]
# Just think of it as a table for now.

# %%
df = load_data_from_google_drive(url='https://drive.google.com/file/d/184JcLbSpArA_uq0DgAv2k892KChJVPHt/view?usp=share_link')

# %%
df
# Out:
#         Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 0         1985      20   1228      81   1328      64    N      0
# 1         1985      25   1106      77   1354      70    H      0
# 2         1985      25   1112      63   1223      56    H      0
# 3         1985      25   1165      70   1432      54    H      0
# 4         1985      25   1192      86   1447      74    H      0
# ...        ...     ...    ...     ...    ...     ...  ...    ...
# 145284    2016     132   1114      70   1419      50    N      0
# 145285    2016     132   1163      72   1272      58    N      0
# 145286    2016     132   1246      82   1401      77    N      1
# 145287    2016     132   1277      66   1345      62    N      0
# 145288    2016     132   1386      87   1433      74    N      0
#
# [145289 rows x 8 columns]

# %% [markdown]
# # The Basics

# %% [markdown]
# Now that we have our dataframe in our variable df, let's look at what it contains. We can use the function **head()** to see the first couple rows of the dataframe (or the function **tail()** to see the last few rows).

# %%
df.head()
# Out:
#    Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 0    1985      20   1228      81   1328      64    N      0
# 1    1985      25   1106      77   1354      70    H      0
# 2    1985      25   1112      63   1223      56    H      0
# 3    1985      25   1165      70   1432      54    H      0
# 4    1985      25   1192      86   1447      74    H      0

# %%
df.tail()
# Out:
#         Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 145284    2016     132   1114      70   1419      50    N      0
# 145285    2016     132   1163      72   1272      58    N      0
# 145286    2016     132   1246      82   1401      77    N      1
# 145287    2016     132   1277      66   1345      62    N      0
# 145288    2016     132   1386      87   1433      74    N      0

# %% [markdown]
# We can see the dimensions of the dataframe using the the **shape** attribute

# %%
df.shape
# Out:
# (145289, 8)

# %% [markdown]
# We can also extract all the column names as a list, by using the **columns** attribute and can extract the rows with the **index** attribute

# %%
df.columns.tolist()
# Out:
# ['Season', 'Daynum', 'Wteam', 'Wscore', 'Lteam', 'Lscore', 'Wloc', 'Numot']

# %% [markdown]
# In order to get a better idea of the type of data that we are dealing with, we can call the **describe()** function to see statistics like mean, min, etc about each column of the dataset.

# %%
df.describe()
# Out:
#               Season         Daynum          Wteam         Wscore  \
# count  145289.000000  145289.000000  145289.000000  145289.000000
# mean     2001.574834      75.223816    1286.720646      76.600321
# std         9.233342      33.287418     104.570275      12.173033
# min      1985.000000       0.000000    1101.000000      34.000000
# 25%      1994.000000      47.000000    1198.000000      68.000000
# 50%      2002.000000      78.000000    1284.000000      76.000000
# 75%      2010.000000     103.000000    1379.000000      84.000000
# max      2016.000000     132.000000    1464.000000     186.000000
#
#                Lteam         Lscore          Numot
# count  145289.000000  145289.000000  145289.000000
# mean     1282.864064      64.497009       0.044387
# std       104.829234      11.380625       0.247819
# min      1101.000000      20.000000       0.000000
# 25%      1191.000000      57.000000       0.000000
# 50%      1280.000000      64.000000       0.000000
# 75%      1375.000000      72.000000       0.000000
# max      1464.000000     150.000000       6.000000

# %% [markdown]
# Okay, so now let's looking at information that we want to extract from the dataframe. Let's say I wanted to know the max value of a certain column. The function **max()** will show you the maximum values of all columns

# %%
df.max()
# Out:
# Season    2016
# Daynum     132
# Wteam     1464
# Wscore     186
# Lteam     1464
# Lscore     150
# Wloc         N
# Numot        6
# dtype: object

# %% [markdown]
# Then, if you'd like to specifically get the max value for a particular column, you pass in the name of the column using the bracket indexing operator

# %%
df['Wscore'].max()
# Out:
# 186

# %% [markdown]
# If you'd like to find the mean of the Losing teams' score.

# %%
df['Lscore'].mean()
# Out:
# 64.49700940883343

# %% [markdown]
# But what if that's not enough? Let's say we want to actually see the game(row) where this max score happened. We can call the **argmax()** function to identify the row index

# %%
df['Wscore'].argmax()
# Out:
# 24970

# %% [markdown]
# One of the most useful functions that you can call on certain columns in a dataframe is the **value_counts()** function. It shows how many times each item appears in the column. This particular command shows the number of games in each season

# %%
df['Season'].value_counts()
# Out:
# Season
# 2016    5369
# 2014    5362
# 2015    5354
# 2013    5320
# 2010    5263
# 2012    5253
# 2009    5249
# 2011    5246
# 2008    5163
# 2007    5043
# 2006    4757
# 2005    4675
# 2003    4616
# 2004    4571
# 2002    4555
# 2000    4519
# 2001    4467
# 1999    4222
# 1998    4167
# 1997    4155
# 1992    4127
# 1991    4123
# 1996    4122
# 1995    4077
# 1994    4060
# 1990    4045
# 1989    4037
# 1993    3982
# 1988    3955
# 1987    3915
# 1986    3783
# 1985    3737
# Name: count, dtype: int64

# %% [markdown]
# **Q**: How many unique seasons are there in the dataset? Use the nunique() function.

# %%
df['Season'].nunique()
# Out:
# 32

# %% [markdown]
# **Q**: Find the team with the most wins. Use the value_counts() function on the Wteam column.

# %%
df["Wteam"].value_counts()
# Out:
# Wteam
# 1181    819
# 1242    804
# 1246    765
# 1314    761
# 1112    746
#        ...
# 1101     18
# 1446     14
# 1118      6
# 1289      6
# 1327      3
# Name: count, Length: 364, dtype: int64

# %% [markdown]
# The team with the most wins is 1181

# %% [markdown]
# # Acessing Values

# %% [markdown]
# Then, in order to get attributes about the game, we need to use the **iloc[]** function. Iloc is definitely one of the more important functions. The main idea is that you want to use it whenever you have the integer index of a certain row that you want to access. As per Pandas documentation, iloc is an "integer-location based indexing for selection by position."

# %%
df.iloc[[df['Wscore'].argmax()]]
# Out:
#        Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 24970    1991      68   1258     186   1109     140    H      0

# %% [markdown]
# Let's take this a step further. Let's say you want to know the game with the highest scoring winning team (this is what we just calculated), but you then want to know how many points the losing team scored.

# %%
df.iloc[[df['Wscore'].argmax()]]['Lscore']
# Out:
# 24970    140
# Name: Lscore, dtype: int64

# %% [markdown]
# When you see data displayed in the above format, you're dealing with a Pandas **Series** object, not a dataframe object.

# %%
type(df.iloc[[df['Wscore'].argmax()]]['Lscore'])
# Out:
# pandas.core.series.Series

# %%
type(df.iloc[[df['Wscore'].argmax()]])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# The following is a summary of the 3 data structures in Pandas (Haven't ever really used Panels yet)
#
# ![](DataStructures.png)

# %% [markdown]
# When you want to access values in a Series, you'll want to just treat the Series like a Python dictionary, so you'd access the value according to its key (which is normally an integer index)

# %%
df.iloc[[df['Wscore'].argmax()]]['Lscore'][24970]
# Out:
# 140

# %% [markdown]
# The other really important function in Pandas is the **loc** function. Contrary to iloc, which is an integer based indexing, loc is a "Purely label-location based indexer for selection by label". Since all the games are ordered from 0 to 145288, iloc and loc are going to be pretty interchangable in this type of dataset

# %%
df.iloc[:3]
# Out:
#    Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 0    1985      20   1228      81   1328      64    N      0
# 1    1985      25   1106      77   1354      70    H      0
# 2    1985      25   1112      63   1223      56    H      0

# %%
df.loc[:3]
# Out:
#    Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 0    1985      20   1228      81   1328      64    N      0
# 1    1985      25   1106      77   1354      70    H      0
# 2    1985      25   1112      63   1223      56    H      0
# 3    1985      25   1165      70   1432      54    H      0

# %% [markdown]
# Notice the slight difference in that iloc is exclusive of the second number, while loc is inclusive.

# %% [markdown]
# Below is an example of how you can use loc to acheive the same task as we did previously with iloc

# %%
df.loc[df['Wscore'].argmax(), 'Lscore']
# Out:
# 140

# %% [markdown]
# A faster version uses the **at()** function. At() is really useful wheneever you know the row label and the column label of the particular value that you want to get.

# %%
df.at[df['Wscore'].argmax(), 'Lscore']
# Out:
# 140

# %% [markdown]
# If you'd like to see more discussion on how loc and iloc are different, check out this great Stack Overflow post: http://stackoverflow.com/questions/31593201/pandas-iloc-vs-ix-vs-loc-explanation. Just remember that **iloc looks at position** and **loc looks at labels**. Loc becomes very important when your row labels aren't integers.

# %% [markdown]
# # Sorting

# %% [markdown]
# Let's say that we want to sort the dataframe in increasing order for the scores of the losing team

# %%
df.sort_values('Lscore').head()
# Out:
#         Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 100027    2008      66   1203      49   1387      20    H      0
# 49310     1997      66   1157      61   1204      21    H      0
# 89021     2006      44   1284      41   1343      21    A      0
# 85042     2005      66   1131      73   1216      22    H      0
# 103660    2009      26   1326      59   1359      22    H      0

# %% [markdown]
# **Q**: Make three dataframes that are sorted by season, winning team, and winning score respectively. Then, Using iloc, select the rows from index 100 to 200 and the columns for season, winning team, and winning score, respectively.

# %%
sorted_season = df.sort_values('Season')

sub1 = sorted_season.iloc[100:200,[0,2,3]]
sub1
# Out:
#       Season  Wteam  Wscore
# 2525    1985   1406      68
# 2526    1985   1410      83
# 2527    1985   1423      58
# 2528    1985   1429      86
# 2529    1985   1440      50
# ...      ...    ...     ...
# 2446    1985   1206      77
# 2447    1985   1212      63
# 2448    1985   1216      64
# 2449    1985   1233      77
# 2450    1985   1249      80
#
# [100 rows x 3 columns]

# %%
sorted_Wteam = df.sort_values('Wteam')
sub2  = sorted_Wteam.iloc[100:200,[0,2,3]]
sub2
# Out:
#         Season  Wteam  Wscore
# 97792     2008   1102      71
# 97721     2008   1102      67
# 96770     2007   1102      67
# 96658     2007   1102      69
# 96454     2007   1102      60
# ...        ...    ...     ...
# 34548     1993   1102      61
# 33628     1993   1102      71
# 32738     1993   1102      69
# 135550    2015   1102      59
# 32610     1993   1102      75
#
# [100 rows x 3 columns]

# %%
sorted_Wscore = df.sort_values('Wscore')
sub3 = sorted_Wscore.iloc[100:200,[0,2,3]]
sub3
# Out:
#         Season  Wteam  Wscore
# 99013     2008   1460      43
# 126840    2013   1366      43
# 126982    2013   1442      43
# 15619     1989   1343      43
# 122700    2012   1349      43
# ...        ...    ...     ...
# 123294    2012   1192      45
# 135433    2015   1438      45
# 72338     2002   1443      45
# 135808    2015   1185      45
# 129196    2013   1380      45
#
# [100 rows x 3 columns]

# %% [markdown]
# **Q**: From these three subsets you obtained above, find the season and winning team for the game with the highest winning score.

# %%
combined_subset = pd.concat([sub1, sub2, sub3])
print(combined_subset)
winner_index = combined_subset['Wscore'].idxmax()

winner_season = combined_subset.loc[winner_index, 'Season']
winner_team = combined_subset.loc[winner_index, 'Wteam']
winner_score = combined_subset.loc[winner_index, 'Wscore']

print(f"The highest score was {winner_score} points.")
print(f"It happened in season: {winner_season}")
print(f"The winning team was: {winner_team}")
# Out:
#         Season  Wteam  Wscore
# 2525      1985   1406      68
# 2526      1985   1410      83
# 2527      1985   1423      58
# 2528      1985   1429      86
# 2529      1985   1440      50
# ...        ...    ...     ...
# 123294    2012   1192      45
# 135433    2015   1438      45
# 72338     2002   1443      45
# 135808    2015   1185      45
# 129196    2013   1380      45
#
# [300 rows x 3 columns]
# The highest score was 105 points.
# It happened in season: 1985
# The winning team was: 1260

# %% [markdown]
# # Filtering Rows Conditionally

# %% [markdown]
# Now, let's say we want to find all of the rows that satisy a particular condition. For example, I want to find all of the games where the winning team scored more than 150 points. The idea behind this command is you want to access the column 'Wscore' of the dataframe df (df['Wscore']), find which entries are above 150 (df['Wscore'] > 150), and then returns only those specific rows in a dataframe format (df[df['Wscore'] > 150]).

# %%
df[df['Wscore'] > 150]
# Out:
#        Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 5269     1986      75   1258     151   1109     107    H      0
# 12046    1988      40   1328     152   1147      84    H      0
# 12355    1988      52   1328     151   1173      99    N      0
# 16040    1989      40   1328     152   1331     122    H      0
# 16853    1989      68   1258     162   1109     144    A      0
# 17867    1989      92   1258     181   1109     150    H      0
# 19653    1990      30   1328     173   1109     101    H      0
# 19971    1990      38   1258     152   1109     137    A      0
# 20022    1990      40   1116     166   1109     101    H      0
# 22145    1990      97   1258     157   1362     115    H      0
# 23582    1991      26   1318     152   1258     123    N      0
# 24341    1991      47   1328     172   1258     112    H      0
# 24970    1991      68   1258     186   1109     140    H      0
# 25656    1991      84   1106     151   1212      97    H      0
# 28687    1992      54   1261     159   1319      86    H      0
# 35023    1993     112   1380     155   1341      91    A      0
# 40060    1995      32   1375     156   1341     114    H      0
# 52600    1998      33   1395     153   1410      87    H      0

# %% [markdown]
# This also works if you have multiple conditions. Let's say we want to find out when the winning team scores more than 150 points and when the losing team scores below 100.

# %%
df[(df['Wscore'] > 150) & (df['Lscore'] < 100)]
# Out:
#        Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 12046    1988      40   1328     152   1147      84    H      0
# 12355    1988      52   1328     151   1173      99    N      0
# 25656    1991      84   1106     151   1212      97    H      0
# 28687    1992      54   1261     159   1319      86    H      0
# 35023    1993     112   1380     155   1341      91    A      0
# 52600    1998      33   1395     153   1410      87    H      0

# %% [markdown]
# **Q**: Create a new column in the DataFrame called 'ScoreDifference' which is the absolute difference between the winning score and the losing score. Filter the DataFrame to only include games where the 'ScoreDifference' is greater than the average 'ScoreDifference' for all games.

# %%
df["score_diff"] = df['Wscore'] - df['Lscore']
mean_score_diff = df["score_diff"].mean()
df[df["score_diff"] > mean_score_diff]
# Out:
#         Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot  score_diff
# 0         1985      20   1228      81   1328      64    N      0          17
# 3         1985      25   1165      70   1432      54    H      0          16
# 6         1985      25   1228      64   1226      44    N      0          20
# 8         1985      25   1260      98   1133      80    H      0          18
# 10        1985      25   1307     103   1288      71    H      0          32
# ...        ...     ...    ...     ...    ...     ...  ...    ...         ...
# 145280    2016     131   1401      71   1261      38    N      0          33
# 145282    2016     131   1433      76   1172      54    N      0          22
# 145284    2016     132   1114      70   1419      50    N      0          20
# 145285    2016     132   1163      72   1272      58    N      0          14
# 145288    2016     132   1386      87   1433      74    N      0          13
#
# [57227 rows x 9 columns]

# %% [markdown]
# **Q**: From this filtered DataFrame, find the season and teams involved in the game with the highest 'ScoreDifference'.

# %%
max_score_diff = df["score_diff"].max()
print(f"Max score difference is: {max_score_diff}")
print(f"Team with max score difference is: {df['Wteam'].iloc[df['score_diff'].argmax()]}")
# Out:
# Max score difference is: 91
# Team with max score difference is: 1409

# %% [markdown]
# # Grouping

# %% [markdown]
# Another important function in Pandas is **groupby()**. This is a function that allows you to group entries by certain attributes (e.g Grouping entries by Wteam number) and then perform operations on them. The following function groups all the entries (games) with the same Wteam number and finds the mean for each group.

# %%
df.groupby('Wteam')['Wscore'].mean()
# Out:
# Wteam
# 1101    78.111111
# 1102    69.893204
# 1103    75.839768
# 1104    75.825944
# 1105    74.960894
#           ...
# 1460    75.531469
# 1461    75.170082
# 1462    79.906021
# 1463    71.720102
# 1464    73.926056
# Name: Wscore, Length: 364, dtype: float64

# %% [markdown]
# This next command groups all the games with the same Wteam number and finds where how many times that specific team won at home, on the road, or at a neutral site

# %%
df.groupby('Wteam')['Wloc'].value_counts().head(9)
# Out:
# Wteam  Wloc
# 1101   H        12
#        A         3
#        N         3
# 1102   H       204
#        A        73
#        N        32
# 1103   H       324
#        A       153
#        N        41
# Name: count, dtype: int64

# %% [markdown]
# Each dataframe has a **values** attribute which is useful because it basically displays your dataframe in a numpy array style format

# %%
df.values
# Out:
# array([[1985, 20, 1228, ..., 'N', 0, 17],
#        [1985, 25, 1106, ..., 'H', 0, 7],
#        [1985, 25, 1112, ..., 'H', 0, 7],
#        ...,
#        [2016, 132, 1246, ..., 'N', 1, 5],
#        [2016, 132, 1277, ..., 'N', 0, 4],
#        [2016, 132, 1386, ..., 'N', 0, 13]], dtype=object)

# %% [markdown]
# Now, you can simply just access elements like you would in an array.

# %%
df.values[0][0]
# Out:
# 1985

# %% [markdown]
# **Q**: Group the DataFrame by season and find the average winning score for each season.

# %%
winning_mean = df.groupby("Season")["Wscore"].mean()
winning_mean
# Out:
# Season
# 1985    74.723040
# 1986    74.813640
# 1987    77.993870
# 1988    79.773704
# 1989    81.728511
# 1990    80.846477
# 1991    82.733932
# 1992    79.992004
# 1993    79.508790
# 1994    81.160345
# 1995    80.096149
# 1996    78.205483
# 1997    76.300842
# 1998    77.229902
# 1999    76.043581
# 2000    76.310467
# 2001    77.088650
# 2002    76.963557
# 2003    75.795061
# 2004    74.971122
# 2005    74.693690
# 2006    74.587555
# 2007    74.829467
# 2008    74.962425
# 2009    74.033721
# 2010    74.652480
# 2011    74.374190
# 2012    73.379973
# 2013    72.840789
# 2014    76.101268
# 2015    72.680799
# 2016    78.295958
# Name: Wscore, dtype: float64

# %% [markdown]
# **Q**: Group the DataFrame by winning team and find the maximum winning score for each team across all seasons.

# %%
df.groupby("Wteam")["Wscore"].max()
# Out:
# Wteam
# 1101     95
# 1102    111
# 1103    109
# 1104    114
# 1105    114
#        ...
# 1460    136
# 1461    112
# 1462    125
# 1463    105
# 1464    115
# Name: Wscore, Length: 364, dtype: int64

# %% [markdown]
# **Q**: Group the DataFrame by both season and winning team. Find the team with the highest average winning score for each season.

# %%
avg_scores = df.groupby(["Season", "Wteam"])["Wscore"].mean()
best_team_indices = avg_scores.groupby("Season").idxmax()
top_teams_per_season = avg_scores.loc[best_team_indices]
display(top_teams_per_season)
# Out:
# Season  Wteam
# 1985    1328      92.800000
# 1986    1109      91.200000
# 1987    1380      95.875000
# 1988    1258     111.750000
# 1989    1258     117.315789
# 1990    1258     126.347826
# 1991    1380     112.312500
# 1992    1380      99.642857
# 1993    1380     101.875000
# 1994    1380     106.583333
# 1995    1206     102.833333
# 1996    1206     103.600000
# 1997    1254      94.142857
# 1998    1395     101.153846
# 1999    1317      95.750000
# 2000    1395      95.647059
# 2001    1395      99.315789
# 2002    1242      92.888889
# 2003    1395      88.222222
# 2004    1194      92.142857
# 2005    1311      91.333333
# 2006    1190      89.533333
# 2007    1440      99.400000
# 2008    1440      94.500000
# 2009    1377      96.200000
# 2010    1440      95.000000
# 2011    1449      90.130435
# 2012    1370      87.400000
# 2013    1377      86.500000
# 2014    1322      92.600000
# 2015    1322      90.733333
# 2016    1146      97.142857
# Name: Wscore, dtype: float64

# %% [markdown]
# **Q**: Create a new DataFrame that counts the number of wins for each team in each season. This will involve grouping by both season and winning team, and then using the count() function.

# %%
df.groupby("Season")["Wteam"].value_counts().reset_index(name='wins')
# Out:
#        Season  Wteam  wins
# 0        1985   1385    27
# 1        1985   1424    27
# 2        1985   1256    26
# 3        1985   1272    26
# 4        1985   1207    25
# ...       ...    ...   ...
# 10167    2016   1427     4
# 10168    2016   1227     3
# 10169    2016   1319     3
# 10170    2016   1369     3
# 10171    2016   1152     1
#
# [10172 rows x 3 columns]

# %% [markdown]
# **Q**: For each season, find the team with the most wins. This will involve creating a DataFrame similar to the one in task 5, and then using the idxmax() function for each season.

# %%
# Create a dataframe with win counts
counts = df.groupby("Season")["Wteam"].value_counts().reset_index(name='wins')
# Extract the rows with the maximum wins per season
most_wins_team = counts.loc[counts.groupby("Season")["wins"].idxmax()]
display(most_wins_team)
# Out:
#       Season  Wteam  wins
# 0       1985   1385    27
# 282     1986   1181    32
# 564     1987   1424    33
# 853     1988   1112    31
# 1143    1989   1328    28
# 1436    1990   1247    29
# 1728    1991   1116    30
# 2023    1992   1181    28
# 2320    1993   1231    28
# 2617    1994   1163    27
# 2918    1995   1116    26
# 3219    1996   1269    31
# 3523    1997   1242    31
# 3828    1998   1242    33
# 4134    1999   1181    32
# 4443    2000   1409    29
# 4759    2001   1181    29
# 5077    2002   1153    30
# 5398    2003   1166    29
# 5725    2004   1390    29
# 6051    2005   1228    32
# 6380    2006   1181    30
# 6714    2007   1242    30
# 7050    2008   1272    33
# 7391    2009   1272    31
# 7738    2010   1242    32
# 8085    2011   1242    32
# 8430    2012   1246    32
# 8775    2013   1211    30
# 9121    2014   1455    33
# 9472    2015   1246    34
# 9821    2016   1242    29

# %% [markdown]
# **Q**: Group the DataFrame by losing team and find the average losing score for each team across all seasons. Compare this with the average winning score for each team from task 3. Are there teams that have a higher average losing score than winning score?

# %%
losing_mean = df.groupby("Lteam")["Lscore"].mean()
print(losing_mean)
winning_mean = df.groupby('Wteam')['Wscore'].mean()
# Out:
# Lteam
# 1101    60.586207
# 1102    59.201507
# 1103    64.117347
# 1104    64.374317
# 1105    61.675373
#           ...
# 1460    63.082915
# 1461    64.661972
# 1462    68.216117
# 1463    60.829213
# 1464    65.187063
# Name: Lscore, Length: 364, dtype: float64

# %%
higher_loss_teams = losing_mean[losing_mean > winning_mean]

print(higher_loss_teams)
# Out:
# Series([], Name: Lscore, dtype: float64)

# %% [markdown]
# As seen there are is no teams, who has a higher losing mean than winning mean

# %% [markdown]
# # Dataframe Iteration

# %% [markdown]
# In order to iterate through dataframes, we can use the **iterrows()** function. Below is an example of what the first two rows look like. Each row in iterrows is a Series object

# %%
for index, row in df.iterrows():
    print(row)
    if index == 1:
        break
# Out:
# Season        1985
# Daynum          20
# Wteam         1228
# Wscore          81
# Lteam         1328
# Lscore          64
# Wloc             N
# Numot            0
# score_diff      17
# Name: 0, dtype: object
# Season        1985
# Daynum          25
# Wteam         1106
# Wscore          77
# Lteam         1354
# Lscore          70
# Wloc             H
# Numot            0
# score_diff       7
# Name: 1, dtype: object

# %% [markdown]
# **Q**: Create a new column 'HighScoringGame' that is 'Yes' if the winning score is greater than 100 and 'No' otherwise. This will require iterating over the rows of the DataFrame and checking the value of the winning score for each row.

# %%
win_margins = []

# Iterate over rows to accumulate win margins
for index, row in df.iterrows():
    win_margins.append("Yes" if row['Wscore'] > 100 else "No")

df['HighScoringGame'] = win_margins
df['HighScoringGame'].value_counts()
# Out:
# HighScoringGame
# No     140409
# Yes      4880
# Name: count, dtype: int64

# %% [markdown]
# **Q**: Calculate the total number of games played by each team, whether they won or lost. This will require iterating over the rows of the DataFrame and updating a dictionary that keeps track of the number of games for each team.

# %%
games_played = {}

# Iterate over rows and update game counts for both winning and losing teams
for index, row in df.iterrows():
    games_played[row['Wteam']] = games_played.get(row['Wteam'], 0) + 1
    games_played[row['Lteam']] = games_played.get(row['Lteam'], 0) + 1




print(games_played)
# Out:
# {1228: 992, 1328: 968, 1106: 855, 1354: 906, 1112: 981, 1223: 363, 1165: 833, 1432: 69, 1192: 908, 1447: 903, 1218: 931, 1337: 922, 1226: 847, 1242: 993, 1268: 969, 1260: 914, 1133: 949, 1305: 922, 1424: 974, 1307: 969, 1288: 925, 1344: 951, 1438: 952, 1374: 916, 1411: 903, 1412: 962, 1397: 963, 1417: 966, 1225: 880, 1116: 980, 1368: 808, 1120: 936, 1391: 879, 1135: 847, 1306: 898, 1143: 947, 1388: 897, 1153: 970, 1184: 863, 1159: 887, 1171: 829, 1216: 930, 1173: 960, 1134: 200, 1177: 942, 1296: 879, 1193: 942, 1265: 934, 1196: 981, 1416: 881, 1206: 938, 1137: 912, 1210: 972, 1149: 824, 1211: 921, 1102: 840, 1234: 968, 1114: 910, 1332: 927, 1243: 927, 1317: 883, 1257: 994, 1231: 969, 1277: 966, 1145: 934, 1278: 948, 1453: 912, 1286: 851, 1186: 849, 1301: 979, 1144: 850, 1325: 942, 1384: 887, 1326: 968, 1248: 896, 1287: 857, 1339: 879, 1334: 899, 1365: 907, 1375: 896, 1126: 906, 1403: 939, 1152: 865, 1423: 931, 1347: 858, 1429: 930, 1428: 931, 1437: 983, 1436: 911, 1172: 879, 1439: 946, 1330: 963, 1443: 942, 1121: 175, 1455: 947, 1249: 873, 1241: 942, 1440: 825, 1314: 1010, 1200: 922, 1323: 950, 1264: 928, 1458: 951, 1104: 975, 1160: 928, 1414: 922, 1181: 1013, 1387: 956, 1183: 871, 1247: 943, 1284: 932, 1402: 847, 1276: 959, 1178: 920, 1364: 890, 1338: 962, 1290: 875, 1376: 945, 1378: 936, 1202: 856, 1396: 979, 1180: 930, 1398: 870, 1399: 860, 1155: 950, 1258: 898, 1448: 947, 1464: 856, 1124: 906, 1341: 857, 1130: 951, 1254: 898, 1204: 862, 1151: 899, 1233: 957, 1220: 933, 1246: 999, 1405: 921, 1280: 946, 1238: 920, 1308: 935, 1431: 937, 1253: 915, 1363: 889, 1348: 938, 1373: 950, 1379: 896, 1270: 861, 1409: 966, 1331: 809, 1444: 916, 1434: 902, 1451: 866, 1139: 923, 1442: 840, 1154: 820, 1456: 891, 1229: 951, 1227: 917, 1259: 913, 1406: 926, 1261: 956, 1272: 992, 1117: 891, 1273: 896, 1163: 977, 1318: 942, 1360: 889, 1393: 993, 1419: 894, 1418: 912, 1281: 977, 1161: 905, 1109: 169, 1309: 840, 1298: 894, 1321: 912, 1285: 865, 1271: 887, 1353: 939, 1351: 929, 1359: 874, 1267: 909, 1361: 915, 1386: 958, 1400: 982, 1322: 854, 1433: 975, 1187: 861, 1245: 927, 1111: 876, 1150: 942, 1119: 868, 1141: 872, 1221: 929, 1122: 903, 1185: 900, 1199: 949, 1201: 947, 1212: 837, 1197: 896, 1140: 965, 1292: 888, 1162: 831, 1319: 843, 1239: 891, 1320: 913, 1371: 946, 1349: 888, 1222: 930, 1382: 914, 1383: 898, 1385: 954, 1390: 932, 1425: 944, 1435: 961, 1463: 838, 1441: 854, 1449: 938, 1123: 906, 1103: 910, 1129: 907, 1209: 891, 1156: 900, 1336: 926, 1174: 913, 1343: 832, 1232: 913, 1203: 933, 1110: 910, 1335: 880, 1283: 952, 1235: 950, 1166: 957, 1311: 839, 1256: 925, 1147: 698, 1250: 898, 1266: 951, 1452: 945, 1269: 946, 1208: 954, 1310: 949, 1329: 941, 1333: 911, 1345: 966, 1263: 898, 1352: 925, 1380: 862, 1446: 48, 1427: 858, 1113: 937, 1408: 808, 1410: 831, 1350: 959, 1450: 913, 1462: 954, 1131: 945, 1190: 891, 1168: 891, 1179: 914, 1304: 953, 1224: 907, 1356: 953, 1426: 859, 1215: 147, 1132: 895, 1217: 828, 1389: 928, 1395: 943, 1461: 914, 1279: 927, 1275: 932, 1293: 886, 1191: 928, 1299: 870, 1401: 940, 1175: 890, 1327: 22, 1207: 923, 1108: 866, 1182: 924, 1274: 915, 1362: 867, 1164: 893, 1118: 27, 1420: 845, 1457: 801, 1148: 844, 1372: 795, 1157: 784, 1421: 799, 1358: 806, 1460: 827, 1198: 812, 1291: 815, 1381: 735, 1251: 755, 1282: 745, 1169: 724, 1302: 200, 1454: 737, 1170: 660, 1138: 728, 1158: 720, 1422: 719, 1369: 682, 1404: 643, 1194: 647, 1407: 639, 1142: 597, 1214: 627, 1459: 575, 1240: 568, 1313: 563, 1115: 520, 1176: 526, 1346: 522, 1237: 519, 1340: 497, 1107: 512, 1357: 500, 1324: 506, 1189: 481, 1125: 506, 1105: 447, 1392: 493, 1219: 466, 1127: 442, 1289: 48, 1415: 418, 1236: 400, 1394: 390, 1205: 405, 1128: 106, 1252: 401, 1366: 384, 1294: 336, 1255: 344, 1430: 325, 1413: 348, 1355: 327, 1244: 322, 1295: 308, 1316: 327, 1445: 107, 1312: 276, 1146: 267, 1167: 260, 1300: 252, 1367: 267, 1342: 260, 1195: 273, 1188: 207, 1377: 210, 1315: 217, 1136: 240, 1370: 222, 1303: 129, 1297: 113, 1213: 84, 1262: 83, 1101: 76, 1230: 64}

# %% [markdown]
# **Q**: For each season, find the game with the highest score difference (winning score - losing score). This will require iterating over the rows of the DataFrame, keeping track of the highest score difference for each season, and updating it if a game with a higher score difference is found.

# %%
highest_diff_per_season = {}

for index, row in df.iterrows():
    season = row['Season']
    diff = row['Wscore'] - row['Lscore']
    
    # Update the season's max difference if this game's difference is higher
    if diff > highest_diff_per_season.get(season,0):
        highest_diff_per_season[season] = diff

print(highest_diff_per_season)
# Out:
# {1985: 60, 1986: 84, 1987: 73, 1988: 68, 1989: 70, 1990: 76, 1991: 68, 1992: 82, 1993: 81, 1994: 69, 1995: 74, 1996: 91, 1997: 80, 1998: 66, 1999: 75, 2000: 75, 2001: 75, 2002: 59, 2003: 72, 2004: 70, 2005: 64, 2006: 72, 2007: 74, 2008: 70, 2009: 68, 2010: 75, 2011: 69, 2012: 62, 2013: 58, 2014: 74, 2015: 69, 2016: 73}

# %% [markdown]
# Remember, iterating over a DataFrame should generally be avoided if a vectorized operation can be used instead, as vectorized operations are usually much faster. However, these tasks are designed to give practice with DataFrame iteration for cases where it might be necessary.

# %% [markdown]
# Vectorized Operation Example: Create a new column 'HighScoringGame' in the DataFrame using a vectorized operation. This column should contain 'Yes' if the winning score is greater than 100 and 'No' otherwise. Use the np.where function from the numpy library for this task.

# %%
import numpy as np
df['HighScoringGame'] = np.where(df['Wscore'] > 100, 'Yes', 'No')
# Out:
# HighScoringGame
# No     140409
# Yes      4880
# Name: count, dtype: int64

# %% [markdown]
# **Q**: Vectorized Operation: Calculate the total number of games played by each team, whether they won or lost. Instead of iterating over the DataFrame, use the value_counts() function on the winning team and losing team columns separately, and then add the two Series together.

# %%
wins =df["Wteam"].value_counts()
loss = df["Lteam"].value_counts()

played_games = wins.add(loss, fill_value=0)
played_games
# Out:
# 1101     76
# 1102    840
# 1103    910
# 1104    975
# 1105    447
#        ...
# 1460    827
# 1461    914
# 1462    954
# 1463    838
# 1464    856
# Name: count, Length: 364, dtype: int64

# %% [markdown]
# **Q**: For each season, find the game with the highest score difference (winning score - losing score). Instead of iterating over the DataFrame, create a new column 'ScoreDifference' using vectorized subtraction, then use the groupby() function and idxmax() function to find the game with the highest score difference for each season.

# %%
df["ScoreDifference"] = df['Wscore'] - df['Lscore']


highest_diff = df.groupby('Season')['ScoreDifference'].idxmax()


highest_diff_games = df.loc[highest_diff]
highest_diff_games
# Out:
#         Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot  \
# 236       1985      33   1361     128   1288      68    H      0
# 4731      1986      60   1314     129   1264      45    N      0
# 8240      1987      51   1155     112   1118      39    H      0
# 12046     1988      40   1328     152   1147      84    H      0
# 16677     1989      64   1242     115   1135      45    H      0
# 19502     1990      26   1181     130   1217      54    H      0
# 25161     1991      73   1163     115   1148      47    H      0
# 27997     1992      30   1116     128   1126      46    H      0
# 33858     1993      86   1328     146   1197      65    H      0
# 36404     1994      47   1228     121   1152      52    H      0
# 39858     1995      26   1246     124   1404      50    H      0
# 44653     1996      48   1409     141   1341      50    H      0
# 49033     1997      56   1278     114   1106      34    H      0
# 52600     1998      33   1395     153   1410      87    H      0
# 57618     1999      58   1268     132   1317      57    H      0
# 60616     2000      19   1261     112   1212      37    H      0
# 65999     2001      41   1196     125   1197      50    H      0
# 70737     2002      50   1328     109   1183      50    H      0
# 74791     2003      33   1403     107   1311      35    H      0
# 79181     2004      29   1328      94   1115      24    H      0
# 83372     2005      18   1403     119   1421      55    H      0
# 89542     2006      60   1400     110   1341      38    H      0
# 94507     2007      59   1401     101   1212      27    H      0
# 97737     2008       4   1182     129   1224      59    H      0
# 103723    2009      27   1314     116   1421      48    H      0
# 108405    2010      15   1397     124   1421      49    H      0
# 114015    2011      22   1388     121   1152      52    H      0
# 118699    2012      11   1345      96   1296      34    H      0
# 124057    2013       7   1235      98   1105      40    H      0
# 131373    2014      61   1256     126   1255      52    H      0
# 134590    2015      11   1181     113   1342      44    H      0
# 140040    2016      12   1139     144   1154      71    H      0
#
#        HighScoringGame  Games_played  ScoreDifference
# 236                Yes          1064               60
# 4731               Yes          1233               84
# 8240               Yes           556               73
# 12046              Yes          1136               68
# 16677              Yes          1329               70
# 19502              Yes          1256               76
# 25161              Yes          1180               68
# 27997              Yes          1228               82
# 33858              Yes          1240               81
# 36404              Yes          1320               69
# 39858              Yes          1204               74
# 44653              Yes          1249               91
# 49033              Yes           976               80
# 52600              Yes          1027               66
# 57618              Yes          1121               75
# 60616              Yes          1140               75
# 65999              Yes          1211               75
# 70737              Yes          1174               59
# 74791              Yes          1021               72
# 79181               No          1046               70
# 83372              Yes           931               64
# 89542              Yes          1297               72
# 94507              Yes          1081               74
# 97737              Yes           969               70
# 103723             Yes          1214               68
# 108405             Yes           999               75
# 114015             Yes          1166               69
# 118699              No          1160               62
# 124057              No           819               58
# 131373             Yes           789               74
# 134590             Yes          1012               69
# 140040             Yes          1145               73

# %% [markdown]
# # Extracting Rows and Columns

# %% [markdown]
# The bracket indexing operator is one way to extract certain columns from a dataframe.

# %%
df[['Wscore', 'Lscore']].head()
# Out:
#    Wscore  Lscore
# 0      81      64
# 1      77      70
# 2      63      56
# 3      70      54
# 4      86      74

# %% [markdown]
# Notice that you can acheive the same result by using the loc function. Loc is a veryyyy versatile function that can help you in a lot of accessing and extracting tasks.

# %%
df.loc[:, ['Wscore', 'Lscore']].head()
# Out:
#    Wscore  Lscore
# 0      81      64
# 1      77      70
# 2      63      56
# 3      70      54
# 4      86      74

# %% [markdown]
# Note the difference is the return types when you use brackets and when you use double brackets.

# %%
type(df['Wscore'])
# Out:
# pandas.core.series.Series

# %%
type(df[['Wscore']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# You've seen before that you can access columns through df['col name']. You can access rows by using slicing operations.

# %%
df[0:3]
# Out:
#    Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot  score_diff  \
# 0    1985      20   1228      81   1328      64    N      0          17
# 1    1985      25   1106      77   1354      70    H      0           7
# 2    1985      25   1112      63   1223      56    H      0           7
#
#   HighScoringGame
# 0              No
# 1              No
# 2              No

# %% [markdown]
# Here's an equivalent using iloc

# %%
df.iloc[0:3,:]
# Out:
#    Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot  score_diff  \
# 0    1985      20   1228      81   1328      64    N      0          17
# 1    1985      25   1106      77   1354      70    H      0           7
# 2    1985      25   1112      63   1223      56    H      0           7
#
#   HighScoringGame
# 0              No
# 1              No
# 2              No

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# One of the big jobs of doing well in Kaggle competitions is that of data cleaning. A lot of times, the CSV file you're given (especially like in the Titanic dataset), you'll have a lot of missing values in the dataset, which you have to identify. The following **isnull** function will figure out if there are any missing values in the dataframe, and will then sum up the total for each column. In this case, we have a pretty clean dataset.

# %%
df.isnull().sum()
# Out:
# Season             0
# Daynum             0
# Wteam              0
# Wscore             0
# Lteam              0
# Lscore             0
# Wloc               0
# Numot              0
# score_diff         0
# HighScoringGame    0
# dtype: int64

# %% [markdown]
# If you do end up having missing values in your datasets, be sure to get familiar with these two functions.
# * **dropna()** - This function allows you to drop all(or some) of the rows that have missing values.
# * **fillna()** - This function allows you replace the rows that have missing values with the value that you pass in.

# %% [markdown]
# # Other Useful Functions

# %% [markdown]
# * **drop()** - This function removes the column or row that you pass in (You also have the specify the axis).
# * **agg()** - The aggregate function lets you compute summary statistics about each group
# * **apply()** - Lets you apply a specific function to any/all elements in a Dataframe or Series
# * **get_dummies()** - Helpful for turning categorical data into one hot vectors.
# * **drop_duplicates()** - Lets you remove identical rows

# %% [markdown]
# # Lots of Other Great Resources

# %% [markdown]
# Pandas has been around for a while and there are a lot of other good resources if you're still interested on getting the most out of this library.
# * http://pandas.pydata.org/pandas-docs/stable/10min.html
# * https://www.datacamp.com/community/tutorials/pandas-tutorial-dataframe-python
# * http://www.gregreda.com/2013/10/26/intro-to-pandas-data-structures/
# * https://www.dataquest.io/blog/pandas-python-tutorial/
# * https://drive.google.com/file/d/0ByIrJAE4KMTtTUtiVExiUGVkRkE/view
# * https://www.youtube.com/playlist?list=PL5-da3qGB5ICCsgW1MxlZ0Hq8LL5U3u9y
